# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="white")
import os
import plotly.express as px
from plotly.subplots import make_subplots
from plotly import graph_objects as go
import warnings
warnings.filterwarnings("ignore")

# %%
controllers= ["disparity_extender","pure_pursuit","e2e"]
opponents = [2,3]
obstacles = [0,5]

original_dfs = []
file_str = "nosimplex_{}_1.000000_{}_{}_0.0_0.0.csv"
collision_str = "nosimplex_collisions_{}_{}_{}_0.0_0.0_cones.csv"

for cntrl in controllers:
    for opp in opponents:
        for obs in obstacles:
            fh = file_str.format(cntrl,opp,obs)
            ch = collision_str.format(cntrl,opp,obs)
            
            
            df = pd.read_csv(fh,header=None)
            df =df.rename(columns={0:'time_str',1:'time_taken_lec',2:'time_taken_safety_controller',3:'area'})
            df['controller'] = cntrl
            
            df['time_taken_lec'] * 100
            df['number_of_opponents'] = opp
            
            df['number_of_obstacles']= obs
            
            if(os.path.exists(ch)):
                c_df = pd.read_csv(ch,header=None)
                df['collision_percentage'] = ((c_df.count()[0])/10)*100
            else:
                df['collision_percentage'] = 0.0
            
            df = df.drop(columns = ["time_taken_safety_controller"])
            
            original_dfs.append(df)
            
dfs = pd.concat(original_dfs)
dfs
# Out:
#                time_str  time_taken_lec     area          controller  \
# 0   28/03/2022/17:06:42        0.826468  2.77279  disparity_extender
# 1   28/03/2022/17:08:52        0.809925  2.77451  disparity_extender
# 2   28/03/2022/17:11:00        0.813758  2.78352  disparity_extender
# 3   28/03/2022/17:13:11        0.828485  2.79316  disparity_extender
# 4   28/03/2022/17:15:22        0.792029  2.75229  disparity_extender
# ..                  ...             ...      ...                 ...
# 5   28/03/2022/16:51:42        0.994941  2.73125                 e2e
# 6   28/03/2022/16:54:56        0.970187  2.71828                 e2e
# 7   28/03/2022/16:58:11        0.958298  2.79501                 e2e
# 8   28/03/2022/17:01:22        0.979883  2.71076                 e2e
# 9   28/03/2022/17:04:32        0.994078  2.69823                 e2e
#
#     number_of_opponents  number_of_obstacles  collision_percentage
# 0                     2                    0                   0.0
# 1                     2                    0                   0.0
# 2                     2                    0                   0.0
# 3                     2                    0                   0.0
# 4                     2                    0                   0.0
# ..                  ...                  ...                   ...
# 5                     3                    5                   0.0
# 6                     3                    5                   0.0
# 7                     3                    5                   0.0
# 8                     3                    5                   0.0
# 9                     3                    5                   0.0
#
# [121 rows x 7 columns]

# %%
dfs.groupby(["controller","number_of_opponents","number_of_obstacles"]).median()
# Out:
#                                                             time_taken_lec  \
# controller         number_of_opponents number_of_obstacles
# disparity_extender 2                   0                          0.814882
#                                        5                          0.805476
#                    3                   0                          0.793990
#                                        5                          0.808458
# e2e                2                   0                          0.155172
#                                        5                          0.804058
#                    3                   0                          0.988978
#                                        5                          0.978673
# pure_pursuit       2                   0                          1.000000
#                                        5                          0.944825
#                    3                   0                          0.966217
#                                        5                          0.942335
#
#                                                                 area  \
# controller         number_of_opponents number_of_obstacles
# disparity_extender 2                   0                    2.779015
#                                        5                    2.795175
#                    3                   0                    2.649975
#                                        5                    2.647460
# e2e                2                   0                    3.022620
#                                        5                    3.004640
#                    3                   0                    2.755485
#                                        5                    2.720080
# pure_pursuit       2                   0                    2.842095
#                                        5                    2.910095
#                    3                   0                    2.714630
#                                        5                    2.701120
#
#                                                             collision_percentage
# controller         number_of_opponents number_of_obstacles
# disparity_extender 2                   0                                     0.0
#                                        5                                     0.0
#                    3                   0                                     0.0
#                                        5                                     0.0
# e2e                2                   0                                   100.0
#                                        5                                   100.0
#                    3                   0                                     0.0
#                                        5                                     0.0
# pure_pursuit       2                   0                                     0.0
#                                        5                                    20.0
#                    3                   0                                     0.0
#                                        5                                    30.0

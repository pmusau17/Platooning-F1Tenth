# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="white")
import os
import plotly.express as px
from plotly.subplots import make_subplots
from plotly import graph_objects as go
import warnings
warnings.filterwarnings("ignore")

# %%
file_str = ['ground_truth_{}','particle_uncertainty_truth_{}']
params = ["0.000000.csv","0.050000.csv","0.100000.csv","0.150000.csv","0.200000.csv","0.250000.csv","0.300000.csv","0.350000.csv","0.400000.csv","0.500000.csv",
"0.550000.csv","0.600000.csv","0.650000.csv","0.700000.csv","0.750000.csv","0.800000.csv"]


original_dfs = []

for st in file_str:
    for val in params:
        
        fh = st.format(val)
        df = pd.read_csv(fh,header=None)
        df =df.rename(columns={0:'time_str',1:'time_taken_lec',2:'time_taken_safety_controller',3:'area'})
        df['parameter_uncertainty']  = float(val.replace(".csv",""))
        df['mode'] = st[:-3]
        original_dfs.append(df)
        
dfs = pd.concat(original_dfs)

# %%
dfs.groupby(['mode','parameter_uncertainty']).mean()
# Out:
#                                                   time_taken_lec  \
# mode                       parameter_uncertainty
# ground_truth               0.00                         0.672971
#                            0.05                         0.649679
#                            0.10                         0.777082
#                            0.15                         0.738399
#                            0.20                         0.636175
#                            0.25                         0.541516
#                            0.30                         0.456875
#                            0.35                         0.388282
#                            0.40                         0.365438
#                            0.50                         0.265498
#                            0.55                         0.265057
#                            0.60                         0.233412
#                            0.65                         0.241462
#                            0.70                         0.219369
#                            0.75                         0.217078
#                            0.80                         0.216232
# particle_uncertainty_truth 0.00                         0.224901
#                            0.05                         0.216538
#                            0.10                         0.193472
#                            0.15                         0.206792
#                            0.20                         0.194201
#                            0.25                         0.203578
#                            0.30                         0.209202
#                            0.35                         0.204993
#                            0.40                         0.134736
#                            0.50                         0.508621
#                            0.55                         0.812575
#                            0.60                         0.729120
#                            0.65                         0.690387
#                            0.70                         0.707517
#                            0.75                         0.599246
#                            0.80                         0.627243
#
#                                                   time_taken_safety_controller  \
# mode                       parameter_uncertainty
# ground_truth               0.00                                       0.327029
#                            0.05                                       0.350321
#                            0.10                                       0.222918
#                            0.15                                       0.261601
#                            0.20                                       0.363825
#                            0.25                                       0.458484
#                            0.30                                       0.543125
#                            0.35                                       0.611718
#                            0.40                                       0.634562
#                            0.50                                       0.734502
#                            0.55                                       0.734943
#                            0.60                                       0.766588
#                            0.65                                       0.758538
#                            0.70                                       0.780631
#                            0.75                                       0.782922
#                            0.80                                       0.783768
# particle_uncertainty_truth 0.00                                       0.775099
#                            0.05                                       0.783462
#                            0.10                                       0.806528
#                            0.15                                       0.793208
#                            0.20                                       0.805799
#                            0.25                                       0.796422
#                            0.30                                       0.790798
#                            0.35                                       0.795007
#                            0.40                                       0.865264
#                            0.50                                       0.491379
#                            0.55                                       0.187425
#                            0.60                                       0.270880
#                            0.65                                       0.309613
#                            0.70                                       0.292484
#                            0.75                                       0.400754
#                            0.80                                       0.372757
#
#                                                          area
# mode                       parameter_uncertainty
# ground_truth               0.00                      2.929028
#                            0.05                      4.874958
#                            0.10                      7.543637
#                            0.15                     10.431963
#                            0.20                     14.804157
#                            0.25                     19.361100
#                            0.30                     24.585407
#                            0.35                     30.908413
#                            0.40                     39.949285
#                            0.50                     65.968650
#                            0.55                     82.529260
#                            0.60                    106.761782
#                            0.65                    135.665025
#                            0.70                    179.225925
#                            0.75                    235.746650
#                            0.80                    294.047925
# particle_uncertainty_truth 0.00                   3902.628053
#                            0.05                   4146.731573
#                            0.10                   3906.860590
#                            0.15                   4239.009757
#                            0.20                   4328.251953
#                            0.25                   4309.312377
#                            0.30                   4654.983812
#                            0.35                   4648.324108
#                            0.40                   4345.232080
#                            0.50                   1276.628183
#                            0.55                    175.570130
#                            0.60                    167.422100
#                            0.65                    275.279500
#                            0.70                    221.396100
#                            0.75                    260.039300
#                            0.80                    348.105100
